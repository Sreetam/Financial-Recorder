# %%
file = open('financials.txt', 'w')

bank = {
    'sbi':20000.49,
    'fed':11270.37,
    'uco':5000.08,
    'ubi':5000.71,
    'ippb':1000.00,
    'posb':11488.46
}

fd = 15000.00
elss = 29526.00
gold = 2
silver = 20

#https://ibjarates.com
goldrate = 50438.0
silverrate = 56042.0

goldworth = gold * goldrate / 10
silverworth =  silver * silverrate / 1000

investments = goldworth + silverworth + elss + fd

credit = {
    'onecard':7603.86,
    'icici':25000 - 23123.09,
    'lazypay':762.0,
    'simpl':0.0,
    'amazonpl':0.0
}

liabilities = sum(credit.values())

projected_expenses = 10074.300000000003 * ((31 / 15) - 1)
eom = sum(bank.values()) - liabilities - projected_expenses - 6000

report = f"""
NETWORTH : {sum(bank.values()) - liabilities + investments}
LIQUID : {sum(bank.values()) - liabilities}

NETWORTH AT END OF MONTH : {eom + investments + 6000}
LIQUID AT END OF MONTH : {eom}

Assets in bank:
    SBI : {bank['sbi']}
    FED : {bank['fed']}
    UBI : {bank['ubi']}
    UCO : {bank['uco']}
    IPB : {bank['ippb']}
    POS : {bank['posb']}
TOTAL : {sum(bank.values())}

Investments:
    ELS : {elss}
    GLD : {goldworth}
    SIL : {silverworth}
    FD  : {fd}
TOTAL : {investments}

Liabilities:
    SBM 1 CC : {credit['onecard']}
    ICICI CC : {credit['icici']}
    AMAZN PL : {credit['amazonpl']}
    SIMPL PL : {credit['simpl']}
    LZYPY PL : {credit['lazypay']}
TOTAL : {liabilities}
"""

file.write(report)
file.close()
print(report)
# Out:
# NETWORTH : 99251.78
# LIQUID : 43517.34
#
# NETWORTH AT END OF MONTH : 88505.85999999999
# LIQUID AT END OF MONTH : 26771.41999999999
#
# Assets in bank:
#     SBI : 20000.49
#     FED : 11270.37
#     UBI : 5000.71
#     UCO : 5000.08
#     IPB : 1000.0
#     POS : 11488.46
# TOTAL : 53760.11
#
# Investments:
#     ELS : 29526.0
#     GLD : 10087.6
#     SIL : 1120.84
#     FD  : 15000.0
# TOTAL : 55734.44
#
# Liabilities:
#     SBM 1 CC : 7603.86
#     ICICI CC : 1876.9099999999999
#     AMAZN PL : 0.0
#     SIMPL PL : 0.0
#     LZYPY PL : 762.0
# TOTAL : 10242.77
