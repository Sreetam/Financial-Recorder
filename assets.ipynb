# %%
file = open('financials.txt', 'w')

bank = {
    'sbi':20000.49,
    'fed':25196.97,
    'uco':5000.08,
    'ubi':5000.71,
    'ippb':1000.00,
    'posb':1488.46
}

fd = 15000.00
elss = 29458.00
gold = 2
silver = 20

#https://ibjarates.com
goldrate = 50771.0
silverrate = 57881.0

goldworth = gold * goldrate / 10
silverworth =  silver * silverrate / 1000

investments = goldworth + silverworth + elss + fd

onecard = 7657.86
icici = 6588.00
paylater = 0.00
liabilities = onecard + icici + paylater

report = f"""
NETWORTH : {sum(bank.values()) - liabilities + investments}
LIQUID : {sum(bank.values()) - liabilities}

Assets in bank:
    SBI : {bank['sbi']}
    FED : {bank['fed']}
    UBI : {bank['ubi']}
    UCO : {bank['uco']}
    IPB : {bank['ippb']}
    POS : {bank['posb']}
TOTAL : {sum(bank.values())}

Investments:
    ELS : {elss}
    GLD : {goldworth}
    SIL : {silverworth}
    FD  : {fd}
TOTAL : {investments}

Liabilities:
    SBM ONECD : {onecard}
    ICICI CCD : {icici}
    PAY LATER : {paylater}
TOTAL : {liabilities}
"""

file.write(report)
file.close()
print(report)
# Out:
# NETWORTH : 99210.67000000001
# LIQUID : 43440.850000000006
#
# Assets in bank:
#     SBI : 20000.49
#     FED : 25196.97
#     UBI : 5000.71
#     UCO : 5000.08
#     IPB : 1000.0
#     POS : 1488.46
# TOTAL : 57686.71000000001
#
# Investments:
#     ELS : 29458.0
#     GLD : 10154.2
#     SIL : 1157.62
#     FD  : 15000.0
# TOTAL : 55769.82
#
# Liabilities:
#     SBM ONECD : 7657.86
#     ICICI CCD : 6588.0
#     PAY LATER : 0.0
# TOTAL : 14245.86
